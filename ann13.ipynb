# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten 
from tensorflow.keras.optimizers import Adam
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load and preprocess the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data() 
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Define the model architecture 
model = Sequential([
Flatten(input_shape=(28, 28)), 
Dense(128, activation='relu'), 
Dense(10, activation='softmax')
])
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Compile the model 
model.compile(optimizer=Adam(learning_rate=0.001),
loss='sparse_categorical_crossentropy', 
metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, batch_size=64, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 938/938 [==============================] - 6s 4ms/step - loss: 0.3063 - accuracy: 0.9144
# Epoch 2/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1383 - accuracy: 0.9602
# Epoch 3/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0975 - accuracy: 0.9719
# Epoch 4/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0744 - accuracy: 0.9782
# Epoch 5/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0585 - accuracy: 0.9826
# Epoch 6/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0463 - accuracy: 0.9865
# Epoch 7/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0387 - accuracy: 0.9882
# Epoch 8/10
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0315 - accuracy: 0.9906
# Epoch 9/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0253 - accuracy: 0.9928
# Epoch 10/10
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0206 - accuracy: 0.9943

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test) 
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0786 - accuracy: 0.9786
# Test Loss: 0.07861045002937317
# Test Accuracy: 0.978600025177002
