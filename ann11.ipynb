# %%
import tensorflow as tf
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load dataset
df = load_breast_cancer()

# %%
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    df.data,
    df.target,
    test_size=0.20,
    random_state=42
)

# %%
# Feature scaling
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Build model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(
        1,
        activation='sigmoid',
        input_shape=(X_train.shape[1],)
    )
])
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\envs\tf\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Compile model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train model
model.fit(
    X_train,
    y_train,
    epochs=5
)
# Out:
# Epoch 1/5
# 15/15 [==============================] - 1s 2ms/step - loss: 0.3283 - accuracy: 0.9121
# Epoch 2/5
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2942 - accuracy: 0.9231
# Epoch 3/5
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2668 - accuracy: 0.9429
# Epoch 4/5
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2453 - accuracy: 0.9451
# Epoch 5/5
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.9495

# %%
# Predict
y_pred = model.predict(X_test)

# Evaluate model
test_loss, test_accuracy = model.evaluate(
    X_test,
    y_test
)

# Print accuracy
print("Accuracy is :", test_accuracy)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2270 - accuracy: 0.9386
# Accuracy is : 0.9385964870452881
